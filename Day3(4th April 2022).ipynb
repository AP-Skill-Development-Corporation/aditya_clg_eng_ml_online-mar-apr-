# %% [markdown]
# ### Today Topics
# - Pandas
# - matplotlib and scikit learn

# %% [markdown]
# #### Pandas
# - Pandas means PanelData(rows and columns)
# - used for data analysis,manipulation and cleaning
# - 2data structures in pandas
#     1. Series and
#     2. DataFrame

# %%
import pandas as pd

# %%
pd.__version__
# Out:
# '0.25.1'

# %%
dir(pd)
# Out:
# ['Categorical',
#  'CategoricalDtype',
#  'CategoricalIndex',
#  'DataFrame',
#  'DateOffset',
#  'DatetimeIndex',
#  'DatetimeTZDtype',
#  'ExcelFile',
#  'ExcelWriter',
#  'Float64Index',
#  'Grouper',
#  'HDFStore',
#  'Index',
#  'IndexSlice',
#  'Int16Dtype',
#  'Int32Dtype',
#  'Int64Dtype',
#  'Int64Index',
#  'Int8Dtype',
#  'Interval',
#  'IntervalDtype',
#  'IntervalIndex',
#  'MultiIndex',
#  'NaT',
#  'NamedAgg',
#  'Period',
#  'PeriodDtype',
#  'PeriodIndex',
#  'RangeIndex',
#  'Series',
#  'SparseArray',
#  'SparseDataFrame',
#  'SparseDtype',
#  'SparseSeries',
#  'Timedelta',
#  'TimedeltaIndex',
#  'Timestamp',
#  'UInt16Dtype',
#  'UInt32Dtype',
#  'UInt64Dtype',
#  'UInt64Index',
#  'UInt8Dtype',
#  '__builtins__',
#  '__cached__',
#  '__doc__',
#  '__docformat__',
#  '__file__',
#  '__getattr__',
#  '__git_version__',
#  '__loader__',
#  '__name__',
#  '__package__',
#  '__path__',
#  '__spec__',
#  '__version__',
#  '_config',
#  '_hashtable',
#  '_lib',
# ...

# %% [markdown]
# #### Series
# - Sequential data either side by side / line by line
# - pd.Series(obj/ele)

# %%
st=input()
print(st)
# Out:
# hi I am Ml trainer from APSSDC
# hi I am Ml trainer from APSSDC

# %%
type(st)
# Out:
# str

# %%
pd.Series(st)
# Out:
# 0    hi I am Ml trainer from APSSDC
# dtype: object

# %%
# convert tuple/list/dict as series

# %%
t=(8,5,6,3,'hi','hello')
print(t)
# Out:
# (8, 5, 6, 3, 'hi', 'hello')

# %%
pd.Series(t)
# Out:
# 0        8
# 1        5
# 2        6
# 3        3
# 4       hi
# 5    hello
# dtype: object

# %%
# example with list
ss=st.split()
ss
# Out:
# ['hi', 'I', 'am', 'Ml', 'trainer', 'from', 'APSSDC']

# %%
pd.Series(ss)
# Out:
# 0         hi
# 1          I
# 2         am
# 3         Ml
# 4    trainer
# 5       from
# 6     APSSDC
# dtype: object

# %%
li=[9,5,6,4,'hi','python',67] # homogenous data structure
pd.Series(li)
# Out:
# 0         9
# 1         5
# 2         6
# 3         4
# 4        hi
# 5    python
# 6        67
# dtype: object

# %%
li # list
# Out:
# [9, 5, 6, 4, 'hi', 'python', 67]

# %%
nums=[5,6,7,8,9,int(input())]
pd.Series(nums)
# Out:
# 90
# 0     5
# 1     6
# 2     7
# 3     8
# 4     9
# 5    90
# dtype: int64

# %%
# convertion of dict into Series
dic={12:'hi',24:'hello',9:90,'clg':'SVEC'}
s=pd.Series(dic)
s
# Out:
# 12        hi
# 24     hello
# 9         90
# clg     SVEC
# dtype: object

# %%
dir(s)
# Out:
# ['T',
#  '_AXIS_ALIASES',
#  '_AXIS_IALIASES',
#  '_AXIS_LEN',
#  '_AXIS_NAMES',
#  '_AXIS_NUMBERS',
#  '_AXIS_ORDERS',
#  '_AXIS_REVERSED',
#  '_HANDLED_TYPES',
#  '__abs__',
#  '__add__',
#  '__and__',
#  '__array__',
#  '__array_priority__',
#  '__array_ufunc__',
#  '__array_wrap__',
#  '__bool__',
#  '__class__',
#  '__contains__',
#  '__copy__',
#  '__deepcopy__',
#  '__delattr__',
#  '__delitem__',
#  '__dict__',
#  '__dir__',
#  '__div__',
#  '__divmod__',
#  '__doc__',
#  '__eq__',
#  '__finalize__',
#  '__float__',
#  '__floordiv__',
#  '__format__',
#  '__ge__',
#  '__getattr__',
#  '__getattribute__',
#  '__getitem__',
#  '__getstate__',
#  '__gt__',
#  '__hash__',
#  '__iadd__',
#  '__iand__',
#  '__ifloordiv__',
#  '__imod__',
#  '__imul__',
#  '__init__',
#  '__init_subclass__',
#  '__int__',
#  '__invert__',
#  '__ior__',
#  '__ipow__',
#  '__isub__',
#  '__iter__',
#  '__itruediv__',
#  '__ixor__',
#  '__le__',
#  '__len__',
#  '__long__',
#  '__lt__',
# ...

# %%
lis=pd.Series(nums)
lis
# Out:
# 0     5
# 1     6
# 2     7
# 3     8
# 4     9
# 5    90
# dtype: int64

# %%
lis.sort_values()
# Out:
# 0     5
# 1     6
# 2     7
# 3     8
# 4     9
# 5    90
# dtype: int64

# %%
li=list(map(int,input().split()))
lis=pd.Series(li)
lis
# Out:
# 90 87 56 1234 56 54 20 98 75
# 0      90
# 1      87
# 2      56
# 3    1234
# 4      56
# 5      54
# 6      20
# 7      98
# 8      75
# dtype: int64

# %%
lis.sort_values() # sorting the series
# Out:
# 6      20
# 5      54
# 2      56
# 4      56
# 8      75
# 1      87
# 0      90
# 7      98
# 3    1234
# dtype: int64

# %%
dir(lis)
# Out:
# ['T',
#  '_AXIS_ALIASES',
#  '_AXIS_IALIASES',
#  '_AXIS_LEN',
#  '_AXIS_NAMES',
#  '_AXIS_NUMBERS',
#  '_AXIS_ORDERS',
#  '_AXIS_REVERSED',
#  '_HANDLED_TYPES',
#  '__abs__',
#  '__add__',
#  '__and__',
#  '__array__',
#  '__array_priority__',
#  '__array_ufunc__',
#  '__array_wrap__',
#  '__bool__',
#  '__class__',
#  '__contains__',
#  '__copy__',
#  '__deepcopy__',
#  '__delattr__',
#  '__delitem__',
#  '__dict__',
#  '__dir__',
#  '__div__',
#  '__divmod__',
#  '__doc__',
#  '__eq__',
#  '__finalize__',
#  '__float__',
#  '__floordiv__',
#  '__format__',
#  '__ge__',
#  '__getattr__',
#  '__getattribute__',
#  '__getitem__',
#  '__getstate__',
#  '__gt__',
#  '__hash__',
#  '__iadd__',
#  '__iand__',
#  '__ifloordiv__',
#  '__imod__',
#  '__imul__',
#  '__init__',
#  '__init_subclass__',
#  '__int__',
#  '__invert__',
#  '__ior__',
#  '__ipow__',
#  '__isub__',
#  '__iter__',
#  '__itruediv__',
#  '__ixor__',
#  '__le__',
#  '__len__',
#  '__long__',
#  '__lt__',
# ...

# %%
help(lis.drop)
# Out:
# Help on method drop in module pandas.core.series:
#
# drop(labels=None, axis=0, index=None, columns=None, level=None, inplace=False, errors='raise') method of pandas.core.series.Series instance
#     Return Series with specified index labels removed.
#
#     Remove elements of a Series based on specifying the index labels.
#     When using a multi-index, labels on different levels can be removed
#     by specifying the level.
#
#     Parameters
#     ----------
#     labels : single label or list-like
#         Index labels to drop.
#     axis : 0, default 0
#         Redundant for application on Series.
#     index, columns : None
#         Redundant for application on Series, but index can be used instead
#         of labels.
#
#         .. versionadded:: 0.21.0
#     level : int or level name, optional
#         For MultiIndex, level for which the labels will be removed.
#     inplace : bool, default False
#         If True, do operation inplace and return None.
# ...

# %%
lis.drop(2) # data at 2nd index is removed
# Out:
# 0      90
# 1      87
# 3    1234
# 4      56
# 5      54
# 6      20
# 7      98
# 8      75
# dtype: int64

# %%
# range and numpy as well
rn=range(400,500,8)
rns=pd.Series(rn)
rns
# Out:
# 0     400
# 1     408
# 2     416
# 3     424
# 4     432
# 5     440
# 6     448
# 7     456
# 8     464
# 9     472
# 10    480
# 11    488
# 12    496
# dtype: int64

# %%
import numpy as np
rna=np.random.randint(10,60,8) # 8 values
pd.Series(rna,index=[1,2,3,4,5,6,7,8]) # user index
# Out:
# 1    11
# 2    51
# 3    19
# 4    43
# 5    32
# 6    37
# 7    53
# 8    32
# dtype: int32

# %%
rns
# Out:
# 0     400
# 1     408
# 2     416
# 3     424
# 4     432
# 5     440
# 6     448
# 7     456
# 8     464
# 9     472
# 10    480
# 11    488
# 12    496
# dtype: int64

# %%
dic
# Out:
# {12: 'hi', 24: 'hello', 9: 90, 'clg': 'SVEC'}

# %%
lis
# Out:
# 0      90
# 1      87
# 2      56
# 3    1234
# 4      56
# 5      54
# 6      20
# 7      98
# 8      75
# dtype: int64

# %%
s.index=[num for num in range(6,10)]
s
# Out:
# 6       hi
# 7    hello
# 8       90
# 9     SVEC
# dtype: object

# %%
dir(s)
# Out:
# ['T',
#  '_AXIS_ALIASES',
#  '_AXIS_IALIASES',
#  '_AXIS_LEN',
#  '_AXIS_NAMES',
#  '_AXIS_NUMBERS',
#  '_AXIS_ORDERS',
#  '_AXIS_REVERSED',
#  '_HANDLED_TYPES',
#  '__abs__',
#  '__add__',
#  '__and__',
#  '__array__',
#  '__array_priority__',
#  '__array_ufunc__',
#  '__array_wrap__',
#  '__bool__',
#  '__class__',
#  '__contains__',
#  '__copy__',
#  '__deepcopy__',
#  '__delattr__',
#  '__delitem__',
#  '__dict__',
#  '__dir__',
#  '__div__',
#  '__divmod__',
#  '__doc__',
#  '__eq__',
#  '__finalize__',
#  '__float__',
#  '__floordiv__',
#  '__format__',
#  '__ge__',
#  '__getattr__',
#  '__getattribute__',
#  '__getitem__',
#  '__getstate__',
#  '__gt__',
#  '__hash__',
#  '__iadd__',
#  '__iand__',
#  '__ifloordiv__',
#  '__imod__',
#  '__imul__',
#  '__init__',
#  '__init_subclass__',
#  '__int__',
#  '__invert__',
#  '__ior__',
#  '__ipow__',
#  '__isub__',
#  '__iter__',
#  '__itruediv__',
#  '__ixor__',
#  '__le__',
#  '__len__',
#  '__long__',
#  '__lt__',
# ...

# %%
help(s.append)
# Out:
# Help on method append in module pandas.core.series:
#
# append(to_append, ignore_index=False, verify_integrity=False) method of pandas.core.series.Series instance
#     Concatenate two or more Series.
#
#     Parameters
#     ----------
#     to_append : Series or list/tuple of Series
#         Series to append with self.
#     ignore_index : bool, default False
#         If True, do not use the index labels.
#
#         .. versionadded:: 0.19.0
#
#     verify_integrity : bool, default False
#         If True, raise Exception on creating index with duplicates.
#
#     Returns
#     -------
#     Series
#         Concatenated Series.
#
#     See Also
#     --------
#     concat : General function to concatenate DataFrame or Series objects.
#
#     Notes
#     -----
#     Iteratively appending to a Series can be more computationally intensive
#     than a single concatenate. A better solution is to append values to a
# ...

# %%
s.append(lis) # concatenation of multiple series
# Out:
# 6       hi
# 7    hello
# 8       90
# 9     SVEC
# 0       90
# 1       87
# 2       56
# 3     1234
# 4       56
# 5       54
# 6       20
# 7       98
# 8       75
# dtype: object

# %%
dir(s)
# Out:
# ['T',
#  '_AXIS_ALIASES',
#  '_AXIS_IALIASES',
#  '_AXIS_LEN',
#  '_AXIS_NAMES',
#  '_AXIS_NUMBERS',
#  '_AXIS_ORDERS',
#  '_AXIS_REVERSED',
#  '_HANDLED_TYPES',
#  '__abs__',
#  '__add__',
#  '__and__',
#  '__array__',
#  '__array_priority__',
#  '__array_ufunc__',
#  '__array_wrap__',
#  '__bool__',
#  '__class__',
#  '__contains__',
#  '__copy__',
#  '__deepcopy__',
#  '__delattr__',
#  '__delitem__',
#  '__dict__',
#  '__dir__',
#  '__div__',
#  '__divmod__',
#  '__doc__',
#  '__eq__',
#  '__finalize__',
#  '__float__',
#  '__floordiv__',
#  '__format__',
#  '__ge__',
#  '__getattr__',
#  '__getattribute__',
#  '__getitem__',
#  '__getstate__',
#  '__gt__',
#  '__hash__',
#  '__iadd__',
#  '__iand__',
#  '__ifloordiv__',
#  '__imod__',
#  '__imul__',
#  '__init__',
#  '__init_subclass__',
#  '__int__',
#  '__invert__',
#  '__ior__',
#  '__ipow__',
#  '__isub__',
#  '__iter__',
#  '__itruediv__',
#  '__ixor__',
#  '__le__',
#  '__len__',
#  '__long__',
#  '__lt__',
# ...

# %% [markdown]
# 1. add()
# 2. all()
# 3. apply()
# 4. any()

# %%
help(s.add)
# Out:
# Help on method add in module pandas.core.ops:
#
# add(other, level=None, fill_value=None, axis=0) method of pandas.core.series.Series instance
#     Return Addition of series and other, element-wise (binary operator `add`).
#
#     Equivalent to ``series + other``, but with support to substitute a fill_value for
#     missing data in one of the inputs.
#
#     Parameters
#     ----------
#     other : Series or scalar value
#     fill_value : None or float value, default None (NaN)
#         Fill existing missing (NaN) values, and any new element needed for
#         successful Series alignment, with this value before computation.
#         If data in both corresponding Series locations is missing
#         the result will be missing.
#     level : int or name
#         Broadcast across a level, matching Index values on the
#         passed MultiIndex level.
#
#     Returns
#     -------
#     Series
#         The result of the operation.
#
#     See Also
#     --------
# ...

# %%
s.add(lis)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-50-11da1a891229> in <module>
# ----> 1 s.add(lis)
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\ops\__init__.py in flex_wrapper(self, other, level, fill_value, axis)
#    1338             self._get_axis_number(axis)
#    1339         if isinstance(other, ABCSeries):
# -> 1340             return self._binop(other, op, level=level, fill_value=fill_value)
#    1341         elif isinstance(other, (np.ndarray, list, tuple)):
#    1342             if len(other) != len(self):
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\series.py in _binop(self, other, func, level, fill_value)
#    2813
#    2814         with np.errstate(all="ignore"):
# -> 2815             result = func(this_vals, other_vals)
#    2816
#    2817         name = ops.get_op_result_name(self, other)
#
# ...

# %%
lis
# Out:
# 0      90
# 1      87
# 2      56
# 3    1234
# 4      56
# 5      54
# 6      20
# 7      98
# 8      75
# dtype: int64

# %%
help(s.all)
# Out:
# Help on method all in module pandas.core.series:
#
# all(axis=0, bool_only=None, skipna=True, level=None, **kwargs) method of pandas.core.series.Series instance
#     Return whether all elements are True, potentially over an axis.
#
#     Returns True unless there at least one element within a series or
#     along a Dataframe axis that is False or equivalent (e.g. zero or
#     empty).
#
#     Parameters
#     ----------
#     axis : {0 or 'index', 1 or 'columns', None}, default 0
#         Indicate which axis or axes should be reduced.
#
#         * 0 / 'index' : reduce the index, return a Series whose index is the
#           original column labels.
#         * 1 / 'columns' : reduce the columns, return a Series whose index is the
#           original index.
#         * None : reduce all axes, return a scalar.
#
#     bool_only : bool, default None
#         Include only boolean columns. If None, will attempt to use everything,
# ...

# %%
s.all()
# Out:
# 'SVEC'

# %%
lis.all()
# Out:
# True

# %%
lis.any()
# Out:
# True

# %%
help(lis.any)
# Out:
# Help on method any in module pandas.core.series:
#
# any(axis=0, bool_only=None, skipna=True, level=None, **kwargs) method of pandas.core.series.Series instance
#     Return whether any element is True, potentially over an axis.
#
#     Returns False unless there at least one element within a series or
#     along a Dataframe axis that is True or equivalent (e.g. non-zero or
#     non-empty).
#
#     Parameters
#     ----------
#     axis : {0 or 'index', 1 or 'columns', None}, default 0
#         Indicate which axis or axes should be reduced.
#
#         * 0 / 'index' : reduce the index, return a Series whose index is the
#           original column labels.
#         * 1 / 'columns' : reduce the columns, return a Series whose index is the
#           original index.
#         * None : reduce all axes, return a scalar.
#
#     bool_only : bool, default None
#         Include only boolean columns. If None, will attempt to use everything,
# ...

# %% [markdown]
# #### DataFrame
# - data is in the form of rows and columns
# - tabular format such as an excel sheet

# %%
dic
# Out:
# {12: 'hi', 24: 'hello', 9: 90, 'clg': 'SVEC'}

# %%
pd.DataFrame(dic,index=[1,2,3])
# Out:
#    12     24   9   clg
# 1  hi  hello  90  SVEC
# 2  hi  hello  90  SVEC
# 3  hi  hello  90  SVEC

# %%
menu={'items':['Idly','Dosa','Roti','Coffee'],
      'Prices':[20,30,35,15]}
df=pd.DataFrame(menu)
df
# Out:
#     items  Prices
# 0    Idly      20
# 1    Dosa      30
# 2    Roti      35
# 3  Coffee      15

# %%
print(df)
# Out:
#     items  Prices
# 0    Idly      20
# 1    Dosa      30
# 2    Roti      35
# 3  Coffee      15

# %%
df.columns
# Out:
# Index(['items', 'Prices'], dtype='object')

# %%
df.dtypes
# Out:
# items     object
# Prices     int64
# dtype: object

# %%
df.shape # (rows,cols)
# Out:
# (4, 2)

# %%
df.size # no.of elements
# Out:
# 8

# %%
df.index # default index# providing user index
# Out:
# RangeIndex(start=0, stop=4, step=1)

# %%
df.index=['R1','R2','R3','R4'] # rows

# %%
df
# Out:
#      items  Prices
# R1    Idly      20
# R2    Dosa      30
# R3    Roti      35
# R4  Coffee      15

# %%
# create the following dataframe
Int     Float    Str
9        9.6      str1
87       45.4     str2
90      34.76     str3
1004    45.3      str4
34       5.6      str5
# Out:
#   File "<ipython-input-70-3568c57619f6>", line 2
#     Int     Float    Str
#                 ^
# SyntaxError: invalid syntax

# %%
mul={'Int':[9,87,90,104,34],
     'Float':(90.6,45.6,78.3,89.5,12.0),
    'Str':["str1","str2","str3","str4","str5"]}
mul
# Out:
# {'Int': [9, 87, 90, 104, 34],
#  'Float': (90.6, 45.6, 78.3, 89.5, 12.0),
#  'Str': ['str1', 'str2', 'str3', 'str4', 'str5']}

# %%
df2=pd.DataFrame(mul,index=[9,8,7,6,5])
df2
# Out:
#    Int  Float   Str
# 9    9   90.6  str1
# 8   87   45.6  str2
# 7   90   78.3  str3
# 6  104   89.5  str4
# 5   34   12.0  str5

# %%
# rename the columns
mul
# Out:
# {'Int': [9, 87, 90, 104, 34],
#  'Float': (90.6, 45.6, 78.3, 89.5, 12.0),
#  'Str': ['str1', 'str2', 'str3', 'str4', 'str5']}

# %%
df2.Str # index/attribute
# Out:
# 9    str1
# 8    str2
# 7    str3
# 6    str4
# 5    str5
# Name: Str, dtype: object

# %%
df2['Int']
# Out:
# 9      9
# 8     87
# 7     90
# 6    104
# 5     34
# Name: Int, dtype: int64

# %%
df2[['Int','Str']] # retrieval of data under multiple cols
# Out:
#    Int   Str
# 9    9  str1
# 8   87  str2
# 7   90  str3
# 6  104  str4
# 5   34  str5

# %%
df2.Int.sum()# int values
# Out:
# 324

# %%
df2.Float.min()
# Out:
# 12.0

# %%
df2['Float'].count() # total no.of values
# Out:
# 5

# %%
# you can combine/merge mutliple dfs if they are equal in size

# %%
mul
# Out:
# {'Int': [9, 87, 90, 104, 34],
#  'Float': (90.6, 45.6, 78.3, 89.5, 12.0),
#  'Str': ['str1', 'str2', 'str3', 'str4', 'str5']}

# %%
df
# Out:
#      items  Prices
# R1    Idly      20
# R2    Dosa      30
# R3    Roti      35
# R4  Coffee      15

# %%
df['New']='I am new'

# %%
df #
# Out:
#      items  Prices       New
# R1    Idly      20  I am new
# R2    Dosa      30  I am new
# R3    Roti      35  I am new
# R4  Coffee      15  I am new

# %% [markdown]
# #### Task
# 1. createtwo equal size dfs , merge,concatenate accourdingly

# %%
dir(df)
# Out:
# ['New',
#  'Prices',
#  'T',
#  '_AXIS_ALIASES',
#  '_AXIS_IALIASES',
#  '_AXIS_LEN',
#  '_AXIS_NAMES',
#  '_AXIS_NUMBERS',
#  '_AXIS_ORDERS',
#  '_AXIS_REVERSED',
#  '__abs__',
#  '__add__',
#  '__and__',
#  '__array__',
#  '__array_priority__',
#  '__array_wrap__',
#  '__bool__',
#  '__class__',
#  '__contains__',
#  '__copy__',
#  '__deepcopy__',
#  '__delattr__',
#  '__delitem__',
#  '__dict__',
#  '__dir__',
#  '__div__',
#  '__doc__',
#  '__eq__',
#  '__finalize__',
#  '__floordiv__',
#  '__format__',
#  '__ge__',
#  '__getattr__',
#  '__getattribute__',
#  '__getitem__',
#  '__getstate__',
#  '__gt__',
#  '__hash__',
#  '__iadd__',
#  '__iand__',
#  '__ifloordiv__',
#  '__imod__',
#  '__imul__',
#  '__init__',
#  '__init_subclass__',
#  '__invert__',
#  '__ior__',
#  '__ipow__',
#  '__isub__',
#  '__iter__',
#  '__itruediv__',
#  '__ixor__',
#  '__le__',
#  '__len__',
#  '__lt__',
#  '__matmul__',
#  '__mod__',
#  '__module__',
#  '__mul__',
#  '__ne__',
#  '__neg__',
# ...

# %%
dir(pd)
# Out:
# ['Categorical',
#  'CategoricalDtype',
#  'CategoricalIndex',
#  'DataFrame',
#  'DateOffset',
#  'DatetimeIndex',
#  'DatetimeTZDtype',
#  'ExcelFile',
#  'ExcelWriter',
#  'Float64Index',
#  'Grouper',
#  'HDFStore',
#  'Index',
#  'IndexSlice',
#  'Int16Dtype',
#  'Int32Dtype',
#  'Int64Dtype',
#  'Int64Index',
#  'Int8Dtype',
#  'Interval',
#  'IntervalDtype',
#  'IntervalIndex',
#  'MultiIndex',
#  'NaT',
#  'NamedAgg',
#  'Period',
#  'PeriodDtype',
#  'PeriodIndex',
#  'RangeIndex',
#  'Series',
#  'SparseArray',
#  'SparseDataFrame',
#  'SparseDtype',
#  'SparseSeries',
#  'Timedelta',
#  'TimedeltaIndex',
#  'Timestamp',
#  'UInt16Dtype',
#  'UInt32Dtype',
#  'UInt64Dtype',
#  'UInt64Index',
#  'UInt8Dtype',
#  '__builtins__',
#  '__cached__',
#  '__doc__',
#  '__docformat__',
#  '__file__',
#  '__getattr__',
#  '__git_version__',
#  '__loader__',
#  '__name__',
#  '__package__',
#  '__path__',
#  '__spec__',
#  '__version__',
#  '_config',
#  '_hashtable',
#  '_lib',
# ...
